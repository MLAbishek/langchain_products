# %%
import os

from openai import OpenAI

client = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key=os.getenv("OPENROUTER_API_KEY"),
)

response = client.chat.completions.create(
  model="mistralai/mistral-7b-instruct",
  messages=[
          {
            "role": "user",
            "content": "How many r's are in the word 'strawberry'?"
          }
        ]
)

ans_mis=response.choices[0].message

# %%
import os

from openai import OpenAI

client = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key=os.getenv("OPENROUTER_API_KEY"),
)

response = client.chat.completions.create(
  model="openai/gpt-oss-120b:free",
  messages=[
          {
            "role": "user",
            "content": "How many r's are in the word 'strawberry'?"
          }
        ]
)

ans_gpt=response.choices[0].message

# %%
import os

from openai import OpenAI

client = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key=os.getenv("OPENROUTER_API_KEY"),
)

response = client.chat.completions.create(
  model="openai/gpt-oss-120b:free",
  messages=[
          {
            "role": "user",
            "content": "How many r's are in the word 'strawberry'?"
          }
        ]
)

ans_gpt=response.choices[0].message
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       1 import os
#       3 from openai import OpenAI
# ----> 5 client = OpenAI(
#       6   base_url="https://openrouter.ai/api/v1",
#       7   api_key=os.getenv("OPENROUTER_API_KEY"),
#       8   temperature=0,
#       9 )
#      11 response = client.chat.completions.create(
#      12   model="openai/gpt-oss-120b:free",
#      13   messages=[
#    (...)     18         ]
#      19 )
#      21 ans_gpt=response.choices[0].message
#
# TypeError: OpenAI.__init__() got an unexpected keyword argument 'temperature'
